# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
X = pd.read_csv('../../data/dengue_features_train.csv')
y_raw = pd.read_csv('../../data/dengue_labels_train.csv')
y = y_raw['total_cases']
X__comp_test = pd.read_csv('../../data/dengue_features_test.csv')

X.head(15)
# Out:
#    city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0    sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1    sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2    sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3    sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4    sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
# 5    sj  1990          23      1990-06-04       NaN  0.174850  0.254314
# 6    sj  1990          24      1990-06-11  0.112900  0.092800  0.205071
# 7    sj  1990          25      1990-06-18  0.072500  0.072500  0.151471
# 8    sj  1990          26      1990-06-25  0.102450  0.146175  0.125571
# 9    sj  1990          27      1990-07-02       NaN  0.121550  0.160683
# 10   sj  1990          28      1990-07-09  0.192875  0.082350  0.191943
# 11   sj  1990          29      1990-07-16  0.291600  0.211800  0.301200
# ...

# %%
# confirm row line up
y_raw.head(15)
# Out:
#    city  year  weekofyear  total_cases
# 0    sj  1990          18            4
# 1    sj  1990          19            5
# 2    sj  1990          20            4
# 3    sj  1990          21            3
# 4    sj  1990          22            6
# 5    sj  1990          23            2
# 6    sj  1990          24            4
# 7    sj  1990          25            5
# 8    sj  1990          26           10
# 9    sj  1990          27            6
# 10   sj  1990          28            8
# 11   sj  1990          29            2
# 12   sj  1990          30            6
# 13   sj  1990          31           17
# 14   sj  1990          32           23

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   city                                   1456 non-null   object
#  1   year                                   1456 non-null   int64
#  2   weekofyear                             1456 non-null   int64
#  3   week_start_date                        1456 non-null   object
#  4   ndvi_ne                                1262 non-null   float64
#  5   ndvi_nw                                1404 non-null   float64
#  6   ndvi_se                                1434 non-null   float64
#  7   ndvi_sw                                1434 non-null   float64
#  8   precipitation_amt_mm                   1443 non-null   float64
#  9   reanalysis_air_temp_k                  1446 non-null   float64
# ...

# %%
X.describe()
# Out:
#               year   weekofyear      ndvi_ne      ndvi_nw      ndvi_se  \
# count  1456.000000  1456.000000  1262.000000  1404.000000  1434.000000
# mean   2001.031593    26.503434     0.142294     0.130553     0.203783
# std       5.408314    15.019437     0.140531     0.119999     0.073860
# min    1990.000000     1.000000    -0.406250    -0.456100    -0.015533
# 25%    1997.000000    13.750000     0.044950     0.049217     0.155087
# 50%    2002.000000    26.500000     0.128817     0.121429     0.196050
# 75%    2005.000000    39.250000     0.248483     0.216600     0.248846
# max    2010.000000    53.000000     0.508357     0.454429     0.538314
#
#            ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# count  1434.000000           1443.000000            1446.000000
# mean      0.202305             45.760388             298.701852
# std       0.083903             43.715537               1.362420
# min      -0.063457              0.000000             294.635714
# ...

# %%
X['reanalysis_sat_precip_amt_mm'].hist()
# Out:
# <AxesSubplot:>

# %%
X['reanalysis_sat_precip_amt_mm'].plot.box()
# Out:
# <AxesSubplot:>

# %%
X[X['weekofyear'] > 52]
# Out:
#      city  year  weekofyear week_start_date  ndvi_ne  ndvi_nw  ndvi_se  \
# 139    sj  1993          53      1993-01-01      NaN      NaN      NaN
# 451    sj  1999          53      1999-01-01      NaN      NaN      NaN
# 763    sj  2005          53      2005-01-01      NaN      NaN      NaN
# 1170   iq  2005          53      2005-01-01      NaN      NaN      NaN
# 1430   iq  2010          53      2010-01-01      NaN      NaN      NaN
#
#       ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# 139       NaN                   NaN                    NaN
# 451       NaN                   NaN                    NaN
# 763       NaN                   NaN                    NaN
# 1170      NaN                   NaN                    NaN
# 1430      NaN                   NaN                    NaN
#
#       reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# 139                     NaN                          NaN
# 451                     NaN                          NaN
# ...

# %%
running_null_total = 0
for col in X.columns:
    print(f'{X[col].isnull().sum()}: {col}')
    running_null_total += X[col].isnull().sum()
    
print(f'Total Nulls: {running_null_total}')
# Out:
# 0: city
# 0: year
# 0: weekofyear
# 0: week_start_date
# 194: ndvi_ne
# 52: ndvi_nw
# 22: ndvi_se
# 22: ndvi_sw
# 13: precipitation_amt_mm
# 10: reanalysis_air_temp_k
# 10: reanalysis_avg_temp_k
# 10: reanalysis_dew_point_temp_k
# 10: reanalysis_max_air_temp_k
# 10: reanalysis_min_air_temp_k
# 10: reanalysis_precip_amt_kg_per_m2
# 10: reanalysis_relative_humidity_percent
# 13: reanalysis_sat_precip_amt_mm
# 10: reanalysis_specific_humidity_g_per_kg
# 10: reanalysis_tdtr_k
# 43: station_avg_temp_c
# 43: station_diur_temp_rng_c
# 20: station_max_temp_c
# 14: station_min_temp_c
# 22: station_precip_mm
# Total Nulls: 548

# %%
tmp = X.dropna()
tmp.shape
# Out:
# (1199, 24)

# %%
sj_data = X[X['city']=='sj'].copy()
iq_data = X[X['city']=='iq'].copy()

# %%
sj_data.describe()
# Out:
#               year  weekofyear     ndvi_ne     ndvi_nw     ndvi_se  \
# count   936.000000  936.000000  745.000000  887.000000  917.000000
# mean   1998.826923   26.503205    0.057925    0.067469    0.177655
# std       5.212076   15.021909    0.107153    0.092479    0.057166
# min    1990.000000    1.000000   -0.406250   -0.456100   -0.015533
# 25%    1994.000000   13.750000    0.004500    0.016425    0.139283
# 50%    1999.000000   26.500000    0.057700    0.068075    0.177186
# 75%    2003.000000   39.250000    0.111100    0.115200    0.212557
# max    2008.000000   53.000000    0.493400    0.437100    0.393129
#
#           ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# count  917.000000            927.000000             930.000000
# mean     0.165956             35.470809             299.163653
# std      0.056073             44.606137               1.236429
# min     -0.063457              0.000000             295.938571
# ...

# %%
iq_data.describe()
# Out:
#               year  weekofyear     ndvi_ne     ndvi_nw     ndvi_se  \
# count   520.000000  520.000000  517.000000  517.000000  517.000000
# mean   2005.000000   26.503846    0.263869    0.238783    0.250126
# std       2.918283   15.029450    0.081370    0.076751    0.077354
# min    2000.000000    1.000000    0.061729    0.035860    0.029880
# 25%    2002.750000   13.750000    0.200000    0.179540    0.194743
# 50%    2005.000000   26.500000    0.263643    0.232971    0.249800
# 75%    2007.250000   39.250000    0.319971    0.293929    0.302300
# max    2010.000000   53.000000    0.508357    0.454429    0.538314
#
#           ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# count  517.000000            516.000000             516.000000
# mean     0.266779             64.245736             297.869538
# std      0.086345             35.218995               1.170997
# min      0.064183              0.000000             294.635714
# ...

# %%
for city in X['city'].unique():
    X[X['city']==city]['weekofyear'].hist()

# %% [markdown]
# Observations:
# - From the info it looks like all features are of the proper dtype
# - the ranges of all the cols seems appropriate, so no outliers to be concerned about
# - col with most nulls is ndvi_ne which is 'Pixel northeast of city centroid' at 194
# - there is a week of the year 53, which is strange, though all other values for these rows are null
# - station_tmp_avg and station_diurn_temp_rng are the next most relevant cols with nulls at 43
# - if dropped all rows with nulls the remaining number of records is 1199, which is 82% of the original dataset
# - the distribution of collection weeks appears similar between the 2 cities
# - City
#     - San Juan
#         - has 936 entries
#         - between years 1990 and 2008
#     - Iquitos
#         - has 520 entries
#         - between years 2000 and 2010

# %%
for col in X.columns:
    fig, ax = plt.subplots()
    ax.hist(X[col])
    plt.xlabel(col)
    plt.ylabel('total cases')
    plt.show()

# %%
for col in X.columns:
    fig, ax = plt.subplots()
    ax.scatter(X[col], y)
    plt.xlabel(col)
    plt.ylabel('total cases')
    plt.show()

# %% [markdown]
# # Cleaning
# - handle nulls
#     - drop or impute?
# - convert dtypes?
# - deal with categorical data
# - scale/standardize/normalize?
#
# Only the city and 'week_start_date' are not numerical - so we'll start with only using numerical data and building the model for both cities combined

# %% [markdown]
# ### We'll start with the simplest model
# - drop all nulls
# - use StandardScaler for linear models (REMEMBER decision trees and ensemble models don't need this)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# %%
# need to combine the feature and lable dfs so that when we drop rows everything will line up
# or use the index to get the proper label rows
numeric_cols = [col for col in X.columns if X[col].dtype in ['int64', 'float64']]
X_clean = X[numeric_cols].dropna().copy()
y_clean = y[X_clean.index]

# %%
X_clean[:17]
# Out:
#     year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0   1990          18  0.122600  0.103725  0.198483  0.177617
# 1   1990          19  0.169900  0.142175  0.162357  0.155486
# 2   1990          20  0.032250  0.172967  0.157200  0.170843
# 3   1990          21  0.128633  0.245067  0.227557  0.235886
# 4   1990          22  0.196200  0.262200  0.251200  0.247340
# 6   1990          24  0.112900  0.092800  0.205071  0.210271
# 7   1990          25  0.072500  0.072500  0.151471  0.133029
# 8   1990          26  0.102450  0.146175  0.125571  0.123600
# 10  1990          28  0.192875  0.082350  0.191943  0.152929
# 11  1990          29  0.291600  0.211800  0.301200  0.280667
# 12  1990          30  0.150567  0.171700  0.226900  0.214557
# 16  1990          34  0.190233  0.168800  0.167657  0.172286
# 17  1990          35  0.252900  0.330750  0.264171  0.284314
# 18  1990          36  0.235400  0.200025  0.283817  0.230443
# ...

# %%
# confirm the same indexes were dropped
y_clean[:17]
# Out:
# 0      4
# 1      5
# 2      4
# 3      3
# 4      6
# 6      4
# 7      5
# 8     10
# 10     8
# 11     2
# 12     6
# 16    21
# 17    28
# 18    24
# 19    20
# 20    40
# 21    27
# Name: total_cases, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_clean, y_clean, test_size=.2, random_state=44)

# %%
scaler = StandardScaler()
# remember we fit_transform the training data but only transform the test data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.metrics import mean_absolute_error
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
print(f'Unscaled R^2: {lin_reg.score(X_train, y_train)}')
y_pred = lin_reg.predict(X_test)
print(f'Unscaled MAE: {mean_absolute_error(y_test, y_pred)}')

lin_reg.fit(X_train_scaled, y_train.ravel())
print(f'Scaled features R^2: {lin_reg.score(X_train_scaled, y_train)}')
y_pred = lin_reg.predict(X_test_scaled)
print(f'Scaled MAE: {mean_absolute_error(y_test, y_pred)}')
# Out:
# Unscaled R^2: 0.2716157179255394
# Unscaled MAE: 16.86111250638205
# Scaled features R^2: 0.27161571792553874
# Scaled MAE: 16.86111250638227

# %% [markdown]
# Ok, so scaling does nothing to help the model!
# What about regularization?

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(normalize=False)
lasso.fit(X_train, y_train)
y_pred = lasso.predict(X_test)
mean_absolute_error(y_test, y_pred)
# Out:
# 16.702939023775144

# %%
len(lasso.coef_)
# Out:
# 22

# %%
len(X_train.columns)
# Out:
# 22

# %%
coef_df = pd.DataFrame(data=lasso.coef_.reshape(1, -1), columns=X_train.columns)
coef_df
# Out:
#      year  weekofyear  ndvi_ne  ndvi_nw  ndvi_se  ndvi_sw  \
# 0 -1.3076    0.224675     -0.0     -0.0     -0.0     -0.0
#
#    precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 0                   0.0                    0.0                    0.0
#
#    reanalysis_dew_point_temp_k  reanalysis_max_air_temp_k  \
# 0                          0.0                        0.0
#
#    reanalysis_min_air_temp_k  reanalysis_precip_amt_kg_per_m2  \
# 0                   0.000418                         0.018865
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 0                             -0.777797                      0.004456
#
#    reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# 0                               5.146801          -1.359432
#
#    station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# 0                 0.0                -0.527466                -0.0
#
#    station_min_temp_c  station_precip_mm
# ...

# %%
from sklearn.model_selection import GridSearchCV

lasso = Lasso(tol=0.4)
params = {'alpha':[1e-15, 1e-10, 1e-8, 1e-4, 1e-3, 1e-2, 1, 5, 10, 20]}

lasso_grid = GridSearchCV(lasso, params, scoring='neg_mean_absolute_error', cv=5)
lasso_grid.fit(X_clean, y_clean)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(tol=0.4),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.0001, 0.001, 0.01, 1,
#                                    5, 10, 20]},
#              scoring='neg_mean_absolute_error')

# %%
print(lasso_grid.best_params_)
print(-lasso_grid.best_score_) # REMEMBER TO NEGATE THE SCORE since we want MAE and the score is neg_mae
# Out:
# {'alpha': 1}
# 16.887374580792574
